# %%
# Imports
import os
import json
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyOAuth

# %%
# Access user content
scope = "user-library-read user-read-recently-played user-top-read"
auth_manager = SpotifyOAuth(client_id=os.getenv('SPOTIPY_CLIENT_ID'), client_secret=os.getenv('SPOTIPY_CLIENT_SECRET'), redirect_uri=os.getenv('SPOTIPY_REDIRECT_URI'), scope=scope)
sp = spotipy.Spotify(auth_manager=auth_manager)
# Out:
# ---------------------------------------------------------------------------
# SpotifyOauthError                         Traceback (most recent call last)
# /tmp/ipykernel_8966/3956313873.py in <module>
#       1 # Access user content
#       2 scope = "user-library-read user-read-recently-played user-top-read"
# ----> 3 auth_manager = SpotifyOAuth(client_id=os.getenv('SPOTIPY_CLIENT_ID'), client_secret=os.getenv('SPOTIPY_CLIENT_SECRET'), redirect_uri=os.getenv('SPOTIPY_REDIRECT_URI'), scope=scope)
#       4 sp = spotipy.Spotify(auth_manager=auth_manager)
#
# ~/.local/lib/python3.8/site-packages/spotipy/oauth2.py in __init__(self, client_id, client_secret, redirect_uri, state, scope, cache_path, username, proxies, show_dialog, requests_session, requests_timeout, open_browser, cache_handler)
#     330         super(SpotifyOAuth, self).__init__(requests_session)
#     331
# --> 332         self.client_id = client_id
#     333         self.client_secret = client_secret
# ...

# %%
# Access recently played
playlist_id = "spotify:playlist:51u8YScD1Ror4je8uh0DHn"
results = sp.playlist(playlist_id)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-830bbec79a57> in <module>
#       1 # Access recently played
#       2 playlist_id = "spotify:playlist:51u8YScD1Ror4je8uh0DHn"
# ----> 3 results = sp.playlist(playlist_id)
#
# C:\Python39\lib\site-packages\spotipy\client.py in playlist(self, playlist_id, fields, market, additional_types)
#     615         """
#     616         plid = self._get_id("playlist", playlist_id)
# --> 617         return self._get(
#     618             "playlists/%s" % (plid),
#     619             fields=fields,
#
# C:\Python39\lib\site-packages\spotipy\client.py in _get(self, url, args, payload, **kwargs)
#     295             kwargs.update(args)
#     296
# --> 297         return self._internal_call("GET", url, payload, kwargs)
#     298
#     299     def _post(self, url, args=None, payload=None, **kwargs):
#
# ...
